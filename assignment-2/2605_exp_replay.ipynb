# %%
from q_deep_learning_replay import QDeepLearningExpReplay

# %%
agent = QDeepLearningExpReplay(1e-3, 0.99, 1, 0.001)

# %%
agent.train(epochs=2000)
# Out:
#   0%|                                                  | 0/2000 [00:00<?, ?it/s]/home/m70944/Documents/e-mds130-reinforcement-learning/.venv/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/m70944/Documents/e-mds130-reinforcement-learning/.venv/lib/python3.8/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#   0%|▏                                        | 10/2000 [00:00<00:29, 68.16it/s]
# epoch: 0, error: nan
#  10%|████                                    | 201/2000 [00:18<03:29,  8.60it/s]
# epoch: 200, error: 4343.85
#  20%|████████                                | 402/2000 [00:48<05:25,  4.91it/s]
# epoch: 400, error: 424242.55
#  30%|████████████                            | 604/2000 [01:41<02:25,  9.58it/s]
# epoch: 600, error: 316685.00
#  40%|████████████████                        | 802/2000 [01:56<01:49, 10.94it/s]
# epoch: 800, error: 280437.18
#  50%|███████████████████▌                   | 1001/2000 [02:44<05:39,  2.95it/s]
# epoch: 1000, error: 203177.32
#  60%|███████████████████████▍               | 1201/2000 [04:10<12:30,  1.06it/s]
# epoch: 1200, error: 133924.75
#  70%|███████████████████████████▎           | 1401/2000 [06:05<02:18,  4.32it/s]
# epoch: 1400, error: 91538.73
#  80%|███████████████████████████████▏       | 1601/2000 [07:02<01:50,  3.60it/s]
# epoch: 1600, error: 100101.11
#  90%|███████████████████████████████████    | 1801/2000 [08:11<01:18,  2.54it/s]
# epoch: 1800, error: 86577.75
# 100%|███████████████████████████████████████| 2000/2000 [09:29<00:00,  3.51it/s]

# %%
import numpy as np

# %%
np.mean(agent.test())
# Out:
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 53.19it/s]
# 139.49
